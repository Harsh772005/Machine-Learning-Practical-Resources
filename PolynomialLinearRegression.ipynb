# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
## for create a dataset for Ploynomial Linear Regression Implementation
X= 6* np.random.randn(100,1)-3
y=0.5*X**2+1.5*X+2+np.random.randn(100,1)

## using this format we create dataset y=0.5*x^2+1.5^x+2+outliers

# %%
plt.plot(X,y,'g')
plt.xlabel('X Dataset')
plt.ylabel('y Dataset')
# Out:
# Text(0, 0.5, 'y Dataset')

# %%
# draw scatter plot for this dataset
plt.scatter(X,y,color='g')
plt.xlabel('X Dataset')
plt.ylabel('y Dataset')
# Out:
# Text(0, 0.5, 'y Dataset')

# %% [markdown]
# ## After ploting our data points we can easily see the we can appl ploynomial linear regression here

# %%
## now we divide dataset in to train test
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=42)

# %%
X_train.shape
# Out:
# (75, 1)

# %%
## lets implement simple linear regression
from sklearn.linear_model import LinearRegression
regression=LinearRegression()
regression.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=regression.predict(X_test)

# %%
## visulize the y_test and y_pred data point with plot function
plt.plot(y_test,color='g')
plt.plot(y_pred,color='r')

# %%
from sklearn.metrics import r2_score
score=r2_score(y_test,y_pred)
print('r2_score :-',score)
# Out:
# r2_score :- 0.07359769376633862

# %%
## lets visulize the model
plt.plot(X_train,regression.predict(X_train),color='r')
plt.scatter(X_train,y_train)
plt.xlabel("X Dataset")
plt.ylabel("Y dataset")
# Out:
# Text(0, 0.5, 'Y dataset')

# %%
## lets apply ploynomial transformation
from sklearn.preprocessing import PolynomialFeatures

# %%
poly=PolynomialFeatures(degree=2,include_bias=True)
X_train_poly=poly.fit_transform(X_train)
X_test_poly=poly.transform(X_test)

# %%
X_train_poly # here first is bais means 1.0000e+00 and 1.5605 is my x1 feature and 2.4352 is my square
# Out:
# array([[ 1.00000000e+00,  1.56053469e+00,  2.43526853e+00],
#        [ 1.00000000e+00, -6.28902665e+00,  3.95518562e+01],
#        [ 1.00000000e+00, -5.89171408e+00,  3.47122948e+01],
#        [ 1.00000000e+00, -4.55886481e+00,  2.07832483e+01],
#        [ 1.00000000e+00, -5.19706465e+00,  2.70094810e+01],
#        [ 1.00000000e+00,  1.66089983e+01,  2.75858824e+02],
#        [ 1.00000000e+00, -5.44403825e-01,  2.96375524e-01],
#        [ 1.00000000e+00, -3.88332000e+00,  1.50801742e+01],
#        [ 1.00000000e+00, -3.61285916e+00,  1.30527513e+01],
#        [ 1.00000000e+00,  3.73918377e+00,  1.39814953e+01],
#        [ 1.00000000e+00, -2.52486266e+00,  6.37493147e+00],
#        [ 1.00000000e+00, -5.13106592e+00,  2.63278374e+01],
#        [ 1.00000000e+00, -2.05296564e+00,  4.21466793e+00],
#        [ 1.00000000e+00,  1.25626263e+00,  1.57819580e+00],
#        [ 1.00000000e+00,  3.07953951e+00,  9.48356362e+00],
#        [ 1.00000000e+00,  1.37320515e+00,  1.88569239e+00],
# ...

# %%
X_test_poly
# Out:
# array([[  1.        ,  -6.14878628,  37.80757272],
#        [  1.        ,   3.96259668,  15.70217246],
#        [  1.        ,  -9.9013752 ,  98.03723084],
#        [  1.        ,   3.3287846 ,  11.08080693],
#        [  1.        ,   1.47000147,   2.16090432],
#        [  1.        ,  -3.87839935,  15.04198148],
#        [  1.        ,   1.40974338,   1.98737638],
#        [  1.        ,  -4.24000405,  17.97763433],
#        [  1.        ,  -8.73924083,  76.37433034],
#        [  1.        ,  -2.01084545,   4.04349942],
#        [  1.        ,  -9.8430289 ,  96.88521783],
#        [  1.        ,  -5.36765962,  28.81176978],
#        [  1.        ,  -3.43576078,  11.80445211],
#        [  1.        ,  -0.77275097,   0.59714406],
#        [  1.        ,  -9.98555548,  99.71131826],
#        [  1.        ,   2.04925933,   4.19946378],
#        [  1.        ,   4.67058208,  21.81433694],
#        [  1.        ,   1.9323553 ,   3.73399699],
# ...

# %%
# now we apply the ploynomial linear regression
from sklearn.metrics import r2_score
regression_1=LinearRegression()
regression_1.fit(X_train_poly,y_train)
y_pred_1=regression_1.predict(X_test_poly)
score_1=r2_score(y_test,y_pred_1)
print("Ploynomial regression score ::",score_1)
# Out:
# Ploynomial regression score :: 0.994557783996166

# %%
print(regression_1.coef_)
# Out:
# [[0.         1.48281132 0.50316606]]

# %%
print(regression_1.intercept_)
# Out:
# [1.799732]

# %%
plt.scatter(X_train,regression_1.predict(X_train_poly))
plt.scatter(X_train,y_train)

# %% [markdown]
# ## pipeline concept in Machine Learning
# ### Ans :- ML pipeline is a means of automating the machine learning workflow by enabling data to be transformed and correlated into a model that can then be analyzed to achieve outputs

# %%
from sklearn.pipeline import Pipeline

# %%
def poly_regression(degree):
    X_new=np.linspace(-3,3,200).reshape(200,1)
    poly_features=PolynomialFeatures(degree=degree,include_bias=True)
    lin_reg=LinearRegression()
    poly_regression=Pipeline([
        ('poly_features',poly_features),
        ('lin_reg',lin_reg)
    ])
    poly_regression.fit(X_train,y_train)
    y_pred_new=poly_regression.predict(X_new)

    ## plotting prediction line
    plt.plot(X_new,y_pred_new,'r',label="Degree"+str(degree),linewidth=2)
    plt.plot(X_train,y_train,'b.',linewidth=3)
    plt.plot(X_test,y_test,'g.',linewidth=3)
    plt.legend(loc="upper left")
    plt.xlabel("X")
    plt.ylabel("y")
    plt.axis([-4,4,0,10])

# %%
poly_regression(5)
